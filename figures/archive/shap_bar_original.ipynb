# %%
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'cm'

# Data
features = ['$p/d$ electron\nratio', 'MPF', 'MSBI']
shap_values = [0.0328, 0.0359, 0.1122]

# Figure size — compact for margin insertion
fig, ax = plt.subplots(figsize=(2, 2))

colors = ['#FFFFFF', '#FFFFFF', '#FFFFFF']

y_pos = range(len(features))
bars = ax.barh(y_pos, shap_values, color=colors, height=0.75, edgecolor='black', linewidth=1)

# Feature names inside bars (left-aligned)
labels = ['$p/d$ ratio', 'MPF', 'MSBI']
#for bar, label in zip(bars, labels):
    #ax.text(0.002, bar.get_y() + bar.get_height()/2-0.05,
    #        label, va='center', ha='left', fontsize=10, fontweight='bold', color='black')

# Value labels — inside for long bars, outside for short bars
#for bar, val in zip(bars, shap_values):
#    if bar.get_width() > 0.06:
        #ax.text(bar.get_width() - 0.002, bar.get_y() + bar.get_height()/2-0.05,
        #        f'{val:.3f}', va='center', ha='right', fontsize=15, fontweight='bold', color='black')
#    else:
        #ax.text(bar.get_width() + 0.002, bar.get_y() + bar.get_height()/2-0.05,
        #        f'{val:.3f}', va='center', ha='left', fontsize=15, fontweight='bold', color='black')

ax.set_yticks([])

#ax.set_xlabel('SHAP Value (eV)', fontsize=7, labelpad=2)
ax.set_xlim(0, 0.13)
#ax.tick_params(axis='both', labelsize=7, length=2, pad=2)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_linewidth(0.5)

plt.tight_layout(pad=0.3)
plt.savefig('shap_bar.png', dpi=600, bbox_inches='tight', transparent=True)
plt.savefig('shap_bar.pdf', bbox_inches='tight', transparent=True)
print("Done")
